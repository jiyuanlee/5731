# %% [markdown]
# <a href="https://colab.research.google.com/github/jiyuanlee/5731/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
3+4
# Out:
# 7

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud

# %%
import matplotlib.pyplot as plt

# %%
content=input()
# Out:
# On May 17, 2012, Meghan posed for the cameras at the USA Network’s Upfront Presentation, wearing a beige miniskirt and ivory sleeveless shell with cut-out open-toed pumps. Her hair appears to have been lightened to a chestnut-auburn shade. This is a look we aren’t likely to see the Duchess of Sussex trying out again because it goes against the Queen’s fashion rules in multiple ways. Find out more dress code rules the royal family needs to follow.

# %%
wordcloud=WordCloud().generate(content)

# %%
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud

# %%
import matplotlib.pyplot as plt

# %%
42minutes42seconds / 60 seconds per minute
# Out:
#   File "<ipython-input-1-a0a979742eb8>", line 1
#     42minutes42seconds / 60 seconds per minute
#                      ^
# SyntaxError: invalid syntax

# %%
42*60+42
# Out:
# 2562

# %%
10/1.61
# Out:
# 6.211180124223602

# %%
（10/1.61）/（2562/3600）
# Out:
#   File "<ipython-input-4-173bdfaa5d79>", line 1
#     （10/1.61）/（2562/3600）
#       ^
# SyntaxError: invalid character in identifier

# %%
(10/1.61)/(2562/3600)
# Out:
# 8.727653570337614

# %%
2562/3600
# Out:
# 0.7116666666666667

# %%
6.2/0.71
# Out:
# 8.732394366197184

# %%
n=6

# %%
class=6
# Out:
#   File "<ipython-input-9-39c096ad4a00>", line 1
#     class=6
#          ^
# SyntaxError: invalid syntax

# %%
43
# Out:
# 43

# %%
n+43
# Out:
# 49

# %%
5
# Out:
# 5

# %%
5
x=5
x+1
# Out:
# 6

# %%
import turtle

# %%
bob=turtle.Turtle()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-2-de719def2fcc> in <module>()
# ----> 1 bob=turtle.Turtle()
#
# /usr/lib/python3.6/turtle.py in __init__(self, shape, undobuffersize, visible)
#    3810                  visible=_CFG["visible"]):
#    3811         if Turtle._screen is None:
# -> 3812             Turtle._screen = Screen()
#    3813         RawTurtle.__init__(self, Turtle._screen,
#    3814                            shape=shape,
#
# /usr/lib/python3.6/turtle.py in Screen()
#    3660     else return the existing one."""
#    3661     if Turtle._screen is None:
# -> 3662         Turtle._screen = _Screen()
#    3663     return Turtle._screen
#    3664
#
# /usr/lib/python3.6/turtle.py in __init__(self)
#    3676         # preserved (perhaps by passing it as an optional parameter)
#    3677         if _Screen._root is None:
# ...
