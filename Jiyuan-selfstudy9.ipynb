# %% [markdown]
# CHAPTER 5

# %%
num_friends=[100,49,89,99,41,40,67,89,78,81,34,78,31,1,20,3,12,34,4,13,15,33,19,11,5,3,6,8,9]

# %%
from collections import Counter

# %%
friend_counts=Counter(num_friends)

# %%
xs=range(101)

# %%
ys=[friend_counts[x] for x in xs]

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(xs,ys)
plt.axis([0,101,0,25])
plt.title("Histogram of Friend Counts")
plt.xlabel("# of friends")
plt.ylabel("# of people")
# Out:
# Text(0, 0.5, '# of people')

# %%
num_points = len(num_friends)

# %%
largest_value=max(num_friends)
smallest_value=min(num_friends)

# %%
sorted_values=sorted(num_friends)
smallest_value=sorted_values[0]
second_smallest_value=sorted_values[1]
second_largest_value=sorted_values[-2]

# %%
def mean(x):
  return sum(x)/len(x)

# %%
mean(num_friends)
# Out:
# 36.96551724137931

# %%
def median(v):
  n=len(v)
  sorted_v=sorted(v)
  midpoint=n//2
  if n%2 ==1:
    return sorted_v[midpoint]
  else:
    lo=midpoint-1
    hi=midpoint
    return (sorted_v[lo+sorted_v[hi]])/2

# %%
median(num_friends)
# Out:
# 31

# %%
def quantile(x,p):
  p_index=int(p*len(x))
  return sorted(x)[p_index]

# %%
quantile(num_friends, 0.10)
quantile(num_friends, 0.25)
quantile(num_friends, 0.75)
quantile(num_friends, 0.90)
# Out:
# 89

# %%
def mode(x):
  counts=Counter(x)
  max_count=max(counts.values())
  return [x_i for x_i, count in counts.iteritems()
         if count == max_count]

# %%
mode(num_friends)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-429334839dc0> in <module>()
# ----> 1 mode(num_friends)
#
# <ipython-input-24-783118342a2c> in mode(x)
#       2   counts=Counter(x)
#       3   max_count=max(counts.values())
# ----> 4   return [x_i for x_i, count in counts.iteritems()
#       5          if count == max_count]
#
# AttributeError: 'Counter' object has no attribute 'iteritems'

# %%
def data_range(x):
  return max(x) - min(x)
data_range(num_friends)
# Out:
# 99

# %%
def de_mean(x):
  x_bar=mean(x)
  return [x_i -x_bar for x_i in x]

# %%
import math

# %%
def variance(x):
  n=len(x)
  deviations = de_mean(x)
  return sum_of_squares(deviations) / (n-1)

# %%
variance(num_friends)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-cf689bf1a8f9> in <module>()
# ----> 1 variance(num_friends)
#
# <ipython-input-29-12a4c42211da> in variance(x)
#       2   n=len(x)
#       3   deviations = de_mean(x)
# ----> 4   return sum_of_squares(deviations) / (n-1)
#
# NameError: name 'sum_of_squares' is not defined

# %%
def standard_deviation(x):
  return math.sqrt(variance(x))

# %%
strandard_deviation(num_friends)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-27effd01c750> in <module>()
# ----> 1 strandard_deviation(num_friends)
#
# NameError: name 'strandard_deviation' is not defined

# %%
def interquartile_range(x):
  return quantile(x, 0.75) - quantile(x, 0.25)

# %%
interquartile_range(num_friends)
# Out:
# 58

# %%
def covariance(x,y):
  n=len(x)
  return dot(de_mean(x), de_mean(y))/(n-1)

# %%
covariance(num_friends,daily_minutes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-d9ab2a6b9c83> in <module>()
# ----> 1 covariance(num_friends,daily_minutes)
#
# NameError: name 'daily_minutes' is not defined

# %%
outlier=num_friends.index(100)

# %%
num_friends_good=[x
                 for i,x in enumerate(num_friends)
                 if i != outlier]

# %%
daily_minutes_good=[x
                   for i,x in enumerate(daily_minutes)
                   if i!=outlier]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-5ed896e34243> in <module>()
#       1 daily_minutes_good=[x
# ----> 2                    for i,x in enumerate(daily_minutes)
#       3                    if i!=outlier]
#
# NameError: name 'daily_minutes' is not defined

# %%
coorelation(num_friends_good,daily_minutes_good)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-87e04564cc98> in <module>()
# ----> 1 coorelation(num_friends_good,daily_minutes_good)
#
# NameError: name 'coorelation' is not defined

# %% [markdown]
# CHAPTER 6

# %%
def random_kid():
  return random.choice(["boy","girl"])

# %%
both_girls=0
older_girl=0
either_girl=0

# %%
import random
random.seed(0)
for  _ in range(10000):
  younger=random_kid()
  older=random_kid()
  if older=="girl":
    older_girl +=1
  if older =="girl" and younger =="girl":
    both_girls+=1
  if older == "girl" or younger =="girl":
    either_girl +=1
  print("P(both | older):", both_girls/older_girl)
  print("P(both | either):", both_girls/either_girl)
# Out:
# P(both | older): 1.0
# P(both | either): 1.0
# P(both | older): 0.5
# P(both | either): 0.5
# P(both | older): 0.6666666666666666
# P(both | either): 0.6666666666666666
# P(both | older): 0.75
# P(both | either): 0.75
# P(both | older): 0.75
# P(both | either): 0.6
# P(both | older): 0.6
# P(both | either): 0.5
# P(both | older): 0.6
# P(both | either): 0.5
# P(both | older): 0.6
# P(both | either): 0.42857142857142855
# P(both | older): 0.6
# P(both | either): 0.375
# P(both | older): 0.5
# P(both | either): 0.3333333333333333
# P(both | older): 0.5
# P(both | either): 0.3
# P(both | older): 0.5714285714285714
# P(both | either): 0.36363636363636365
# P(both | older): 0.5714285714285714
# P(both | either): 0.3333333333333333
# P(both | older): 0.625
# P(both | either): 0.38461538461538464
# P(both | older): 0.625
# P(both | either): 0.35714285714285715
# P(both | older): 0.625
# P(both | either): 0.35714285714285715
# P(both | older): 0.625
# P(both | either): 0.3333333333333333
# P(both | older): 0.6666666666666666
# P(both | either): 0.375
# P(both | older): 0.6
# P(both | either): 0.35294117647058826
# P(both | older): 0.6
# P(both | either): 0.35294117647058826
# P(both | older): 0.6
# P(both | either): 0.35294117647058826
# P(both | older): 0.5454545454545454
# P(both | either): 0.3333333333333333
# P(both | older): 0.5454545454545454
# P(both | either): 0.3333333333333333
# P(both | older): 0.5833333333333334
# P(both | either): 0.3684210526315789
# P(both | older): 0.5384615384615384
# P(both | either): 0.35
# P(both | older): 0.5384615384615384
# P(both | either): 0.3333333333333333
# P(both | older): 0.5384615384615384
# P(both | either): 0.3181818181818182
# P(both | older): 0.5714285714285714
# P(both | either): 0.34782608695652173
# P(both | older): 0.5333333333333333
# P(both | either): 0.3333333333333333
# P(both | older): 0.5333333333333333
# P(both | either): 0.32
# P(both | older): 0.5333333333333333
# P(both | either): 0.3076923076923077
# P(both | older): 0.5333333333333333
# P(both | either): 0.3076923076923077
# P(both | older): 0.5
# P(both | either): 0.2962962962962963
# P(both | older): 0.5
# P(both | either): 0.2857142857142857
# P(both | older): 0.5
# P(both | either): 0.2857142857142857
# P(both | older): 0.5
# P(both | either): 0.2857142857142857
# P(both | older): 0.47058823529411764
# P(both | either): 0.27586206896551724
# P(both | older): 0.47058823529411764
# P(both | either): 0.26666666666666666
# P(both | older): 0.4444444444444444
# P(both | either): 0.25806451612903225
# P(both | older): 0.47368421052631576
# P(both | either): 0.28125
# P(both | older): 0.5
# P(both | either): 0.30303030303030304
# P(both | older): 0.47619047619047616
# P(both | either): 0.29411764705882354
# P(both | older): 0.45454545454545453
# P(both | either): 0.2857142857142857
# P(both | older): 0.45454545454545453
# P(both | either): 0.2777777777777778
# P(both | older): 0.45454545454545453
# P(both | either): 0.2777777777777778
# P(both | older): 0.45454545454545453
# P(both | either): 0.2702702702702703
# P(both | older): 0.43478260869565216
# P(both | either): 0.2631578947368421
# P(both | older): 0.4166666666666667
# P(both | either): 0.2564102564102564
# P(both | older): 0.4166666666666667
# P(both | either): 0.25
# P(both | older): 0.4166666666666667
# P(both | either): 0.25
# P(both | older): 0.4166666666666667
# P(both | either): 0.25
# P(both | older): 0.4166666666666667
# P(both | either): 0.25
# P(both | older): 0.4166666666666667
# P(both | either): 0.25
# P(both | older): 0.4
# P(both | either): 0.24390243902439024
# P(both | older): 0.38461538461538464
# P(both | either): 0.23809523809523808
# P(both | older): 0.38461538461538464
# P(both | either): 0.23809523809523808
# P(both | older): 0.38461538461538464
# P(both | either): 0.23809523809523808
# P(both | older): 0.38461538461538464
# P(both | either): 0.23809523809523808
# P(both | older): 0.38461538461538464
# P(both | either): 0.23255813953488372
# P(both | older): 0.38461538461538464
# P(both | either): 0.23255813953488372
# P(both | older): 0.38461538461538464
# P(both | either): 0.22727272727272727
# P(both | older): 0.38461538461538464
# P(both | either): 0.2222222222222222
# P(both | older): 0.38461538461538464
# P(both | either): 0.2222222222222222
# P(both | older): 0.4074074074074074
# P(both | either): 0.2391304347826087
# P(both | older): 0.4074074074074074
# P(both | either): 0.23404255319148937
# P(both | older): 0.39285714285714285
# P(both | either): 0.22916666666666666
# P(both | older): 0.39285714285714285
# P(both | either): 0.22916666666666666
# P(both | older): 0.39285714285714285
# P(both | either): 0.22448979591836735
# P(both | older): 0.41379310344827586
# P(both | either): 0.24
# P(both | older): 0.41379310344827586
# P(both | either): 0.23529411764705882
# P(both | older): 0.41379310344827586
# P(both | either): 0.23529411764705882
# P(both | older): 0.41379310344827586
# P(both | either): 0.23529411764705882
# P(both | older): 0.43333333333333335
# P(both | either): 0.25
# P(both | older): 0.41935483870967744
# P(both | either): 0.24528301886792453
# P(both | older): 0.41935483870967744
# P(both | either): 0.24528301886792453
# P(both | older): 0.4375
# P(both | either): 0.25925925925925924
# P(both | older): 0.45454545454545453
# P(both | either): 0.2727272727272727
# P(both | older): 0.47058823529411764
# P(both | either): 0.2857142857142857
# P(both | older): 0.47058823529411764
# P(both | either): 0.2857142857142857
# P(both | older): 0.47058823529411764
# P(both | either): 0.2807017543859649
# P(both | older): 0.47058823529411764
# P(both | either): 0.27586206896551724
# P(both | older): 0.47058823529411764
# P(both | either): 0.2711864406779661
# P(both | older): 0.45714285714285713
# P(both | either): 0.26666666666666666
# P(both | older): 0.4722222222222222
# P(both | either): 0.2786885245901639
# P(both | older): 0.4722222222222222
# P(both | either): 0.27419354838709675
# P(both | older): 0.4864864864864865
# P(both | either): 0.2857142857142857
# P(both | older): 0.4864864864864865
# P(both | either): 0.28125
# P(both | older): 0.4864864864864865
# P(both | either): 0.28125
# P(both | older): 0.4864864864864865
# P(both | either): 0.27692307692307694
# P(both | older): 0.4864864864864865
# P(both | either): 0.27692307692307694
# P(both | older): 0.5
# P(both | either): 0.2878787878787879
# P(both | older): 0.5
# P(both | either): 0.2835820895522388
# P(both | older): 0.5128205128205128
# P(both | either): 0.29411764705882354
# P(both | older): 0.5128205128205128
# P(both | either): 0.29411764705882354
# P(both | older): 0.5128205128205128
# P(both | either): 0.2898550724637681
# P(both | older): 0.5128205128205128
# P(both | either): 0.2857142857142857
# P(both | older): 0.525
# P(both | either): 0.29577464788732394
# P(both | older): 0.525
# P(both | either): 0.29577464788732394
# P(both | older): 0.5365853658536586
# P(both | either): 0.3055555555555556
# P(both | older): 0.5476190476190477
# P(both | either): 0.3150684931506849
# P(both | older): 0.5348837209302325
# P(both | either): 0.3108108108108108
# P(both | older): 0.5348837209302325
# P(both | either): 0.3108108108108108
# P(both | older): 0.5348837209302325
# P(both | either): 0.3108108108108108
# P(both | older): 0.5454545454545454
# P(both | either): 0.32
# P(both | older): 0.5454545454545454
# P(both | either): 0.3157894736842105
# P(both | older): 0.5454545454545454
# P(both | either): 0.3157894736842105
# P(both | older): 0.5454545454545454
# P(both | either): 0.3157894736842105
# P(both | older): 0.5454545454545454
# P(both | either): 0.3157894736842105
# P(both | older): 0.5333333333333333
# P(both | either): 0.3116883116883117
# P(both | older): 0.5333333333333333
# P(both | either): 0.3076923076923077
# P(both | older): 0.5217391304347826
# P(both | either): 0.3037974683544304
# P(both | older): 0.5217391304347826
# P(both | either): 0.3
# P(both | older): 0.5106382978723404
# P(both | either): 0.2962962962962963
# P(both | older): 0.5106382978723404
# P(both | either): 0.2926829268292683
# P(both | older): 0.5106382978723404
# P(both | either): 0.2891566265060241
# P(both | older): 0.5106382978723404
# P(both | either): 0.2857142857142857
# P(both | older): 0.5
# P(both | either): 0.2823529411764706
# P(both | older): 0.5
# P(both | either): 0.2823529411764706
# P(both | older): 0.5
# P(both | either): 0.2823529411764706
# P(both | older): 0.5102040816326531
# P(both | either): 0.29069767441860467
# P(both | older): 0.5102040816326531
# P(both | either): 0.28735632183908044
# P(both | older): 0.52
# P(both | either): 0.29545454545454547
# P(both | older): 0.5294117647058824
# P(both | either): 0.30337078651685395
# P(both | older): 0.5294117647058824
# P(both | either): 0.30337078651685395
# P(both | older): 0.5384615384615384
# P(both | either): 0.3111111111111111
# P(both | older): 0.5384615384615384
# P(both | either): 0.3111111111111111
# P(both | older): 0.5283018867924528
# P(both | either): 0.3076923076923077
# P(both | older): 0.5370370370370371
# P(both | either): 0.31521739130434784
# P(both | older): 0.5370370370370371
# P(both | either): 0.3118279569892473
# P(both | older): 0.5370370370370371
# P(both | either): 0.30851063829787234
# P(both | older): 0.5272727272727272
# P(both | either): 0.30526315789473685
# P(both | older): 0.5272727272727272
# P(both | either): 0.30526315789473685
# P(both | older): 0.5357142857142857
# P(both | either): 0.3125
# P(both | older): 0.5357142857142857
# P(both | either): 0.30927835051546393
# P(both | older): 0.5357142857142857
# P(both | either): 0.30612244897959184
# P(both | older): 0.5357142857142857
# P(both | either): 0.30303030303030304
# P(both | older): 0.5263157894736842
# P(both | either): 0.3
# P(both | older): 0.5263157894736842
# P(both | either): 0.3
# P(both | older): 0.5344827586206896
# P(both | either): 0.3069306930693069
# P(both | older): 0.5423728813559322
# P(both | either): 0.3137254901960784
# P(both | older): 0.5423728813559322
# P(both | either): 0.3106796116504854
# P(both | older): 0.5333333333333333
# P(both | either): 0.3076923076923077
# P(both | older): 0.5409836065573771
# P(both | either): 0.3142857142857143
# P(both | older): 0.5409836065573771
# P(both | either): 0.3113207547169811
# P(both | older): 0.5409836065573771
# P(both | either): 0.308411214953271
# P(both | older): 0.5483870967741935
# P(both | either): 0.3148148148148148
# P(both | older): 0.5396825396825397
# P(both | either): 0.3119266055045872
# P(both | older): 0.5396825396825397
# P(both | either): 0.3090909090909091
# P(both | older): 0.53125
# P(both | either): 0.3063063063063063
# P(both | older): 0.53125
# P(both | either): 0.3063063063063063
# P(both | older): 0.53125
# P(both | either): 0.3063063063063063
# P(both | older): 0.53125
# P(both | either): 0.3063063063063063
# P(both | older): 0.53125
# P(both | either): 0.30357142857142855
# P(both | older): 0.5230769230769231
# P(both | either): 0.3008849557522124
# P(both | older): 0.5303030303030303
# P(both | either): 0.30701754385964913
# P(both | older): 0.5303030303030303
# P(both | either): 0.30434782608695654
# P(both | older): 0.5303030303030303
# P(both | either): 0.3017241379310345
# P(both | older): 0.5303030303030303
# P(both | either): 0.29914529914529914
# P(both | older): 0.5303030303030303
# P(both | either): 0.2966101694915254
# P(both | older): 0.5303030303030303
# P(both | either): 0.29411764705882354
# P(both | older): 0.5303030303030303
# P(both | either): 0.2916666666666667
# P(both | older): 0.5303030303030303
# P(both | either): 0.2916666666666667
# P(both | older): 0.5303030303030303
# P(both | either): 0.2892561983471074
# P(both | older): 0.5223880597014925
# P(both | either): 0.28688524590163933
# P(both | older): 0.5294117647058824
# P(both | either): 0.2926829268292683
# P(both | older): 0.5294117647058824
# P(both | either): 0.2926829268292683
# P(both | older): 0.5294117647058824
# P(both | either): 0.2926829268292683
# P(both | older): 0.5294117647058824
# P(both | either): 0.2926829268292683
# P(both | older): 0.5362318840579711
# P(both | either): 0.29838709677419356
# P(both | older): 0.5362318840579711
# P(both | either): 0.296
# P(both | older): 0.5285714285714286
# P(both | either): 0.29365079365079366
# P(both | older): 0.5211267605633803
# P(both | either): 0.29133858267716534
# P(both | older): 0.5277777777777778
# P(both | either): 0.296875
# P(both | older): 0.5342465753424658
# P(both | either): 0.3023255813953488
# P(both | older): 0.5342465753424658
# P(both | either): 0.3
# P(both | older): 0.5342465753424658
# P(both | either): 0.3
# P(both | older): 0.5405405405405406
# P(both | either): 0.3053435114503817
# P(both | older): 0.5405405405405406
# P(both | either): 0.30303030303030304
# P(both | older): 0.5333333333333333
# P(both | either): 0.3007518796992481
# P(both | older): 0.5263157894736842
# P(both | either): 0.29850746268656714
# P(both | older): 0.5324675324675324
# P(both | either): 0.3037037037037037
# P(both | older): 0.5324675324675324
# P(both | either): 0.3037037037037037
# P(both | older): 0.5324675324675324
# P(both | either): 0.3037037037037037
# P(both | older): 0.5324675324675324
# P(both | either): 0.3037037037037037
# P(both | older): 0.5256410256410257
# P(both | either): 0.3014705882352941
# P(both | older): 0.5189873417721519
# P(both | either): 0.29927007299270075
# P(both | older): 0.5189873417721519
# P(both | either): 0.2971014492753623
# P(both | older): 0.5125
# P(both | either): 0.2949640287769784
# P(both | older): 0.5185185185185185
# P(both | either): 0.3
# P(both | older): 0.5185185185185185
# P(both | either): 0.3
# P(both | older): 0.5121951219512195
# P(both | either): 0.2978723404255319
# P(both | older): 0.5060240963855421
# P(both | either): 0.29577464788732394
# P(both | older): 0.5119047619047619
# P(both | either): 0.3006993006993007
# P(both | older): 0.5119047619047619
# P(both | either): 0.2986111111111111
# P(both | older): 0.5119047619047619
# P(both | either): 0.2986111111111111
# P(both | older): 0.5058823529411764
# P(both | either): 0.296551724137931
# P(both | older): 0.5116279069767442
# P(both | either): 0.3013698630136986
# P(both | older): 0.5057471264367817
# P(both | either): 0.29931972789115646
# P(both | older): 0.5113636363636364
# P(both | either): 0.30405405405405406
# P(both | older): 0.5168539325842697
# P(both | either): 0.3087248322147651
# P(both | older): 0.5168539325842697
# P(both | either): 0.30666666666666664
# P(both | older): 0.5168539325842697
# P(both | either): 0.30666666666666664
# P(both | older): 0.5111111111111111
# P(both | either): 0.304635761589404
# P(both | older): 0.5111111111111111
# P(both | either): 0.3026315789473684
# P(both | older): 0.5054945054945055
# P(both | either): 0.3006535947712418
# P(both | older): 0.5054945054945055
# P(both | either): 0.2987012987012987
# P(both | older): 0.5054945054945055
# P(both | either): 0.2967741935483871
# P(both | older): 0.5
# P(both | either): 0.2948717948717949
# P(both | older): 0.5
# P(both | either): 0.2929936305732484
# P(both | older): 0.5053763440860215
# P(both | either): 0.2974683544303797
# P(both | older): 0.5053763440860215
# P(both | either): 0.29559748427672955
# P(both | older): 0.5
# P(both | either): 0.29375
# P(both | older): 0.5
# P(both | either): 0.29375
# P(both | older): 0.5
# P(both | either): 0.29375
# P(both | older): 0.5
# P(both | either): 0.2919254658385093
# P(both | older): 0.5
# P(both | either): 0.29012345679012347
# P(both | older): 0.5052631578947369
# P(both | either): 0.294478527607362
# P(both | older): 0.5052631578947369
# P(both | either): 0.294478527607362
# P(both | older): 0.5104166666666666
# P(both | either): 0.29878048780487804
# P(both | older): 0.5051546391752577
# P(both | either): 0.296969696969697
# P(both | older): 0.5
# P(both | either): 0.29518072289156627
# P(both | older): 0.5
# P(both | either): 0.2934131736526946
# P(both | older): 0.5
# P(both | either): 0.2934131736526946
# P(both | older): 0.5050505050505051
# P(both | either): 0.2976190476190476
# P(both | older): 0.5050505050505051
# P(both | either): 0.2958579881656805
# P(both | older): 0.51
# P(both | either): 0.3
# P(both | older): 0.51
# P(both | either): 0.3
# P(both | older): 0.504950495049505
# P(both | either): 0.2982456140350877
# P(both | older): 0.504950495049505
# P(both | either): 0.29651162790697677
# P(both | older): 0.504950495049505
# P(both | either): 0.29651162790697677
# P(both | older): 0.5
# P(both | either): 0.2947976878612717
# P(both | older): 0.5
# P(both | either): 0.29310344827586204
# P(both | older): 0.49514563106796117
# P(both | either): 0.2914285714285714
# P(both | older): 0.49514563106796117
# P(both | either): 0.2897727272727273
# P(both | older): 0.49038461538461536
# P(both | either): 0.288135593220339
# P(both | older): 0.49038461538461536
# P(both | either): 0.288135593220339
# P(both | older): 0.49038461538461536
# P(both | either): 0.28651685393258425
# P(both | older): 0.4857142857142857
# P(both | either): 0.2849162011173184
# P(both | older): 0.49056603773584906
# P(both | either): 0.28888888888888886
# P(both | older): 0.48598130841121495
# P(both | either): 0.287292817679558
# P(both | older): 0.49074074074074076
# P(both | either): 0.29120879120879123
# P(both | older): 0.48623853211009177
# P(both | either): 0.2896174863387978
# P(both | older): 0.48623853211009177
# P(both | either): 0.2896174863387978
# P(both | older): 0.48623853211009177
# P(both | either): 0.28804347826086957
# P(both | older): 0.4909090909090909
# P(both | either): 0.2918918918918919
# P(both | older): 0.4909090909090909
# P(both | either): 0.2918918918918919
# P(both | older): 0.4864864864864865
# P(both | either): 0.2903225806451613
# P(both | older): 0.4864864864864865
# P(both | either): 0.2903225806451613
# P(both | older): 0.4864864864864865
# P(both | either): 0.2903225806451613
# P(both | older): 0.4864864864864865
# P(both | either): 0.2903225806451613
# P(both | older): 0.48214285714285715
# P(both | either): 0.2887700534759358
# P(both | older): 0.48214285714285715
# P(both | either): 0.2872340425531915
# P(both | older): 0.48214285714285715
# P(both | either): 0.2872340425531915
# P(both | older): 0.4778761061946903
# P(both | either): 0.2857142857142857
# P(both | older): 0.47368421052631576
# P(both | either): 0.28421052631578947
# P(both | older): 0.4782608695652174
# P(both | either): 0.2879581151832461
# P(both | older): 0.4782608695652174
# P(both | either): 0.2879581151832461
# P(both | older): 0.47413793103448276
# P(both | either): 0.2864583333333333
# P(both | older): 0.47863247863247865
# P(both | either): 0.29015544041450775
# P(both | older): 0.4830508474576271
# P(both | either): 0.29381443298969073
# P(both | older): 0.4830508474576271
# P(both | either): 0.2923076923076923
# P(both | older): 0.4830508474576271
# P(both | either): 0.2923076923076923
# P(both | older): 0.4830508474576271
# P(both | either): 0.29081632653061223
# P(both | older): 0.4830508474576271
# P(both | either): 0.2893401015228426
# P(both | older): 0.4830508474576271
# P(both | either): 0.2893401015228426
# P(both | older): 0.4830508474576271
# P(both | either): 0.2878787878787879
# P(both | older): 0.4830508474576271
# P(both | either): 0.2878787878787879
# P(both | older): 0.48739495798319327
# P(both | either): 0.2914572864321608
# P(both | older): 0.48739495798319327
# P(both | either): 0.29
# P(both | older): 0.48739495798319327
# P(both | either): 0.29
# P(both | older): 0.48739495798319327
# P(both | either): 0.2885572139303483
# P(both | older): 0.48739495798319327
# P(both | either): 0.2885572139303483
# P(both | older): 0.49166666666666664
# P(both | either): 0.29207920792079206
# P(both | older): 0.49166666666666664
# P(both | either): 0.29064039408866993
# P(both | older): 0.49586776859504134
# P(both | either): 0.29411764705882354
# P(both | older): 0.49586776859504134
# P(both | either): 0.2926829268292683
# P(both | older): 0.4918032786885246
# P(both | either): 0.2912621359223301
# P(both | older): 0.4918032786885246
# P(both | either): 0.2898550724637681
# P(both | older): 0.4959349593495935
# P(both | either): 0.2932692307692308
# P(both | older): 0.49193548387096775
# P(both | either): 0.291866028708134
# P(both | older): 0.496
# P(both | either): 0.29523809523809524
# P(both | older): 0.49206349206349204
# P(both | either): 0.2938388625592417
# P(both | older): 0.49606299212598426
# P(both | either): 0.2971698113207547
# P(both | older): 0.49606299212598426
# P(both | either): 0.2971698113207547
# P(both | older): 0.4921875
# P(both | either): 0.29577464788732394
# P(both | older): 0.4921875
# P(both | either): 0.29577464788732394
# P(both | older): 0.49612403100775193
# P(both | either): 0.29906542056074764
# P(both | older): 0.49230769230769234
# P(both | either): 0.29767441860465116
# P(both | older): 0.49230769230769234
# P(both | either): 0.2962962962962963
# P(both | older): 0.48854961832061067
# P(both | either): 0.29493087557603687
# P(both | older): 0.48854961832061067
# P(both | either): 0.29357798165137616
# P(both | older): 0.49242424242424243
# P(both | either): 0.2968036529680365
# P(both | older): 0.48872180451127817
# P(both | either): 0.29545454545454547
# P(both | older): 0.48507462686567165
# P(both | either): 0.29411764705882354
# P(both | older): 0.48148148148148145
# P(both | either): 0.2927927927927928
# P(both | older): 0.48148148148148145
# P(both | either): 0.2914798206278027
# P(both | older): 0.47794117647058826
# P(both | either): 0.29017857142857145
# P(both | older): 0.4744525547445255
# P(both | either): 0.28888888888888886
# P(both | older): 0.47101449275362317
# P(both | either): 0.28761061946902655
# P(both | older): 0.47101449275362317
# P(both | either): 0.28634361233480177
# P(both | older): 0.47101449275362317
# P(both | either): 0.2850877192982456
# P(both | older): 0.4748201438848921
# P(both | either): 0.28820960698689957
# P(both | older): 0.4748201438848921
# P(both | either): 0.28820960698689957
# P(both | older): 0.4748201438848921
# P(both | either): 0.28695652173913044
# P(both | older): 0.4714285714285714
# P(both | either): 0.2857142857142857
# P(both | older): 0.475177304964539
# P(both | either): 0.28879310344827586
# P(both | older): 0.475177304964539
# P(both | either): 0.2875536480686695
# P(both | older): 0.4788732394366197
# P(both | either): 0.2905982905982906
# P(both | older): 0.4788732394366197
# P(both | either): 0.28936170212765955
# P(both | older): 0.4788732394366197
# P(both | either): 0.28936170212765955
# P(both | older): 0.4755244755244755
# P(both | either): 0.288135593220339
# P(both | older): 0.4791666666666667
# P(both | either): 0.2911392405063291
# P(both | older): 0.4791666666666667
# P(both | either): 0.2911392405063291
# P(both | older): 0.4791666666666667
# P(both | either): 0.2911392405063291
# P(both | older): 0.4827586206896552
# P(both | either): 0.29411764705882354
# P(both | older): 0.4827586206896552
# P(both | either): 0.2928870292887029
# P(both | older): 0.4827586206896552
# P(both | either): 0.2928870292887029
# P(both | older): 0.4863013698630137
# P(both | either): 0.29583333333333334
# P(both | older): 0.4897959183673469
# P(both | either): 0.2987551867219917
# P(both | older): 0.49324324324324326
# P(both | either): 0.30165289256198347
# P(both | older): 0.49324324324324326
# P(both | either): 0.30165289256198347
# P(both | older): 0.49324324324324326
# P(both | either): 0.30165289256198347
# P(both | older): 0.4966442953020134
# P(both | either): 0.3045267489711934
# P(both | older): 0.4966442953020134
# P(both | either): 0.30327868852459017
# P(both | older): 0.5
# P(both | either): 0.30612244897959184
# P(both | older): 0.5033112582781457
# P(both | either): 0.3089430894308943
# P(both | older): 0.5
# P(both | either): 0.3076923076923077
# P(both | older): 0.5032679738562091
# P(both | either): 0.31048387096774194
# P(both | older): 0.5032679738562091
# P(both | either): 0.3092369477911647
# P(both | older): 0.5064935064935064
# P(both | either): 0.312
# P(both | older): 0.5032258064516129
# P(both | either): 0.3107569721115538
# P(both | older): 0.5032258064516129
# P(both | either): 0.3107569721115538
# P(both | older): 0.5
# P(both | either): 0.30952380952380953
# P(both | older): 0.5031847133757962
# P(both | either): 0.31225296442687744
# P(both | older): 0.5031847133757962
# P(both | either): 0.31225296442687744
# P(both | older): 0.5
# P(both | either): 0.3110236220472441
# P(both | older): 0.4968553459119497
# P(both | either): 0.30980392156862746
# P(both | older): 0.4968553459119497
# P(both | either): 0.30980392156862746
# P(both | older): 0.49375
# P(both | either): 0.30859375
# P(both | older): 0.49375
# P(both | either): 0.30739299610894943
# P(both | older): 0.4906832298136646
# P(both | either): 0.3062015503875969
# P(both | older): 0.4906832298136646
# P(both | either): 0.3062015503875969
# P(both | older): 0.49382716049382713
# P(both | either): 0.3088803088803089
# P(both | older): 0.49693251533742333
# P(both | either): 0.31153846153846154
# P(both | older): 0.49390243902439024
# P(both | either): 0.3103448275862069
# P(both | older): 0.49696969696969695
# P(both | either): 0.31297709923664124
# P(both | older): 0.4939759036144578
# P(both | either): 0.311787072243346
# P(both | older): 0.49101796407185627
# P(both | either): 0.3106060606060606
# P(both | older): 0.49101796407185627
# P(both | either): 0.3106060606060606
# P(both | older): 0.4880952380952381
# P(both | either): 0.30943396226415093
# P(both | older): 0.4911242603550296
# P(both | either): 0.31203007518796994
# P(both | older): 0.49411764705882355
# P(both | either): 0.3146067415730337
# P(both | older): 0.49411764705882355
# P(both | either): 0.31343283582089554
# P(both | older): 0.49122807017543857
# P(both | either): 0.31226765799256506
# P(both | older): 0.49122807017543857
# P(both | either): 0.31226765799256506
# P(both | older): 0.49122807017543857
# P(both | either): 0.3111111111111111
# P(both | older): 0.49122807017543857
# P(both | either): 0.3111111111111111
# P(both | older): 0.4883720930232558
# P(both | either): 0.30996309963099633
# P(both | older): 0.4883720930232558
# P(both | either): 0.30996309963099633
# P(both | older): 0.48554913294797686
# P(both | either): 0.3088235294117647
# P(both | older): 0.4827586206896552
# P(both | either): 0.3076923076923077
# P(both | older): 0.4857142857142857
# P(both | either): 0.3102189781021898
# P(both | older): 0.4857142857142857
# P(both | either): 0.3090909090909091
# P(both | older): 0.48863636363636365
# P(both | either): 0.3115942028985507
# P(both | older): 0.4915254237288136
# P(both | either): 0.3140794223826715
# P(both | older): 0.4915254237288136
# P(both | either): 0.3129496402877698
# P(both | older): 0.4943820224719101
# P(both | either): 0.3154121863799283
# P(both | older): 0.4943820224719101
# P(both | either): 0.3154121863799283
# P(both | older): 0.4943820224719101
# P(both | either): 0.3154121863799283
# P(both | older): 0.4943820224719101
# P(both | either): 0.3142857142857143
# P(both | older): 0.4943820224719101
# P(both | either): 0.31316725978647686
# P(both | older): 0.4943820224719101
# P(both | either): 0.31316725978647686
# P(both | older): 0.4943820224719101
# P(both | either): 0.3120567375886525
# P(both | older): 0.4943820224719101
# P(both | either): 0.31095406360424027
# P(both | older): 0.4943820224719101
# P(both | either): 0.30985915492957744
# P(both | older): 0.4943820224719101
# P(both | either): 0.3087719298245614
# P(both | older): 0.49162011173184356
# P(both | either): 0.3076923076923077
# P(both | older): 0.49444444444444446
# P(both | either): 0.31010452961672474
# P(both | older): 0.4972375690607735
# P(both | either): 0.3125
# P(both | older): 0.4972375690607735
# P(both | either): 0.3125
# P(both | older): 0.4945054945054945
# P(both | either): 0.31141868512110726
# P(both | older): 0.4945054945054945
# P(both | either): 0.31141868512110726
# P(both | older): 0.4945054945054945
# P(both | either): 0.3103448275862069
# P(both | older): 0.4918032786885246
# P(both | either): 0.30927835051546393
# P(both | older): 0.4945652173913043
# P(both | either): 0.3116438356164384
# P(both | older): 0.4972972972972973
# P(both | either): 0.31399317406143346
# P(both | older): 0.5
# P(both | either): 0.3163265306122449
# P(both | older): 0.5
# P(both | either): 0.3163265306122449
# P(both | older): 0.5
# P(both | either): 0.3152542372881356
# P(both | older): 0.49732620320855614
# P(both | either): 0.3141891891891892
# P(both | older): 0.5
# P(both | either): 0.3164983164983165
# P(both | older): 0.4973544973544973
# P(both | either): 0.31543624161073824
# P(both | older): 0.5
# P(both | either): 0.3177257525083612
# P(both | older): 0.5
# P(both | either): 0.31666666666666665
# P(both | older): 0.5
# P(both | either): 0.31666666666666665
# P(both | older): 0.5
# P(both | either): 0.31666666666666665
# P(both | older): 0.4973821989528796
# P(both | either): 0.31561461794019935
# P(both | older): 0.4947916666666667
# P(both | either): 0.31456953642384106
# P(both | older): 0.49222797927461137
# P(both | either): 0.31353135313531355
# P(both | older): 0.49222797927461137
# P(both | either): 0.3125
# P(both | older): 0.49222797927461137
# P(both | either): 0.3125
# P(both | older): 0.49222797927461137
# P(both | either): 0.3114754098360656
# P(both | older): 0.4896907216494845
# P(both | either): 0.3104575163398693
# P(both | older): 0.49230769230769234
# P(both | either): 0.3127035830618892
# P(both | older): 0.49230769230769234
# P(both | either): 0.3116883116883117
# P(both | older): 0.49230769230769234
# P(both | either): 0.3106796116504854
# P(both | older): 0.49489795918367346
# P(both | either): 0.31290322580645163
# P(both | older): 0.49746192893401014
# P(both | either): 0.31511254019292606
# P(both | older): 0.49746192893401014
# P(both | either): 0.3141025641025641
# P(both | older): 0.49746192893401014
# P(both | either): 0.3141025641025641
# P(both | older): 0.49746192893401014
# P(both | either): 0.3141025641025641
# P(both | older): 0.49746192893401014
# P(both | either): 0.31309904153354634
# P(both | older): 0.494949494949495
# P(both | either): 0.31210191082802546
# P(both | older): 0.49246231155778897
# P(both | either): 0.3111111111111111
# P(both | older): 0.49246231155778897
# P(both | either): 0.3111111111111111
# P(both | older): 0.495
# P(both | either): 0.31329113924050633
# P(both | older): 0.4925373134328358
# P(both | either): 0.31230283911671924
# P(both | older): 0.4900990099009901
# P(both | either): 0.3113207547169811
# P(both | older): 0.4900990099009901
# P(both | either): 0.3113207547169811
# P(both | older): 0.4876847290640394
# P(both | either): 0.3103448275862069
# P(both | older): 0.4876847290640394
# P(both | either): 0.309375
# P(both | older): 0.49019607843137253
# P(both | either): 0.3115264797507788
# P(both | older): 0.49019607843137253
# P(both | either): 0.3105590062111801
# P(both | older): 0.49019607843137253
# P(both | either): 0.3105590062111801
# P(both | older): 0.4926829268292683
# P(both | either): 0.3126934984520124
# P(both | older): 0.4926829268292683
# P(both | either): 0.3126934984520124
# P(both | older): 0.4926829268292683
# P(both | either): 0.3117283950617284
# P(both | older): 0.4926829268292683
# P(both | either): 0.3117283950617284
# P(both | older): 0.4926829268292683
# P(both | either): 0.3117283950617284
# P(both | older): 0.4926829268292683
# P(both | either): 0.31076923076923074
# P(both | older): 0.4926829268292683
# P(both | either): 0.31076923076923074
# P(both | older): 0.49029126213592233
# P(both | either): 0.3098159509202454
# P(both | older): 0.49029126213592233
# P(both | either): 0.308868501529052
# P(both | older): 0.49029126213592233
# P(both | either): 0.3079268292682927
# P(both | older): 0.48792270531400966
# P(both | either): 0.3069908814589666
# P(both | older): 0.49038461538461536
# P(both | either): 0.3090909090909091
# P(both | older): 0.49038461538461536
# P(both | either): 0.3081570996978852
# P(both | older): 0.49038461538461536
# P(both | either): 0.3081570996978852
# P(both | older): 0.49282296650717705
# P(both | either): 0.3102409638554217
# P(both | older): 0.49282296650717705
# P(both | either): 0.30930930930930933
# P(both | older): 0.49282296650717705
# P(both | either): 0.3083832335329341
# P(both | older): 0.49282296650717705
# P(both | either): 0.3074626865671642
# P(both | older): 0.49523809523809526
# P(both | either): 0.30952380952380953
# P(both | older): 0.49523809523809526
# P(both | either): 0.3086053412462908
# P(both | older): 0.49523809523809526
# P(both | either): 0.3086053412462908
# P(both | older): 0.49523809523809526
# P(both | either): 0.3076923076923077
# P(both | older): 0.4976303317535545
# P(both | either): 0.30973451327433627
# P(both | older): 0.49528301886792453
# P(both | either): 0.3088235294117647
# P(both | older): 0.49528301886792453
# P(both | either): 0.30791788856304986
# P(both | older): 0.49528301886792453
# P(both | either): 0.30701754385964913
# P(both | older): 0.49528301886792453
# P(both | either): 0.30612244897959184
# P(both | older): 0.49295774647887325
# P(both | either): 0.30523255813953487
# P(both | older): 0.49065420560747663
# P(both | either): 0.30434782608695654
# P(both | older): 0.49065420560747663
# P(both | either): 0.30434782608695654
# P(both | older): 0.49065420560747663
# P(both | either): 0.30434782608695654
# P(both | older): 0.49065420560747663
# P(both | either): 0.30434782608695654
# P(both | older): 0.49065420560747663
# P(both | either): 0.30346820809248554
# P(both | older): 0.4883720930232558
# P(both | either): 0.3025936599423631
# P(both | older): 0.4883720930232558
# P(both | either): 0.3017241379310345
# P(both | older): 0.4861111111111111
# P(both | either): 0.3008595988538682
# P(both | older): 0.4861111111111111
# P(both | either): 0.3
# P(both | older): 0.48847926267281105
# P(both | either): 0.301994301994302
# P(both | older): 0.48623853211009177
# P(both | either): 0.30113636363636365
# P(both | older): 0.4885844748858447
# P(both | either): 0.3031161473087819
# P(both | older): 0.4863636363636364
# P(both | either): 0.3022598870056497
# P(both | older): 0.48868778280542985
# P(both | either): 0.30422535211267604
# P(both | older): 0.48868778280542985
# P(both | either): 0.30422535211267604
# P(both | older): 0.49099099099099097
# P(both | either): 0.3061797752808989
# P(both | older): 0.49099099099099097
# P(both | either): 0.3061797752808989
# P(both | older): 0.49099099099099097
# P(both | either): 0.3061797752808989
# P(both | older): 0.48878923766816146
# P(both | either): 0.30532212885154064
# P(both | older): 0.48878923766816146
# P(both | either): 0.30532212885154064
# P(both | older): 0.48878923766816146
# P(both | either): 0.30532212885154064
# P(both | older): 0.48878923766816146
# P(both | either): 0.30532212885154064
# P(both | older): 0.48660714285714285
# P(both | either): 0.30446927374301674
# P(both | older): 0.48444444444444446
# P(both | either): 0.30362116991643456
# P(both | older): 0.48444444444444446
# P(both | either): 0.30362116991643456
# P(both | older): 0.48672566371681414
# P(both | either): 0.3055555555555556
# P(both | older): 0.48672566371681414
# P(both | either): 0.3047091412742382
# P(both | older): 0.4845814977973568
# P(both | either): 0.30386740331491713
# P(both | older): 0.4824561403508772
# P(both | either): 0.30303030303030304
# P(both | older): 0.4824561403508772
# P(both | either): 0.3021978021978022
# P(both | older): 0.4824561403508772
# P(both | either): 0.3013698630136986
# P(both | older): 0.4824561403508772
# P(both | either): 0.3005464480874317
# P(both | older): 0.4847161572052402
# P(both | either): 0.3024523160762943
# P(both | older): 0.48695652173913045
# P(both | either): 0.30434782608695654
# P(both | older): 0.48695652173913045
# P(both | either): 0.3035230352303523
# P(both | older): 0.48917748917748916
# P(both | either): 0.3054054054054054
# P(both | older): 0.48917748917748916
# P(both | either): 0.3045822102425876
# P(both | older): 0.48917748917748916
# P(both | either): 0.30376344086021506
# P(both | older): 0.49137931034482757
# P(both | either): 0.30563002680965146
# P(both | older): 0.4892703862660944
# P(both | either): 0.3048128342245989
# P(both | older): 0.49145299145299143
# P(both | either): 0.30666666666666664
# P(both | older): 0.49145299145299143
# P(both | either): 0.30666666666666664
# P(both | older): 0.49145299145299143
# P(both | either): 0.3058510638297872
# P(both | older): 0.49361702127659574
# P(both | either): 0.3076923076923077
# P(both | older): 0.4915254237288136
# P(both | either): 0.30687830687830686
# P(both | older): 0.4936708860759494
# P(both | either): 0.3087071240105541
# P(both | older): 0.4936708860759494
# P(both | either): 0.3087071240105541
# P(both | older): 0.4936708860759494
# P(both | either): 0.3078947368421053
# P(both | older): 0.4936708860759494
# P(both | either): 0.30708661417322836
# P(both | older): 0.49159663865546216
# P(both | either): 0.306282722513089
# P(both | older): 0.49159663865546216
# P(both | either): 0.306282722513089
# P(both | older): 0.4895397489539749
# P(both | either): 0.30548302872062666
# P(both | older): 0.49166666666666664
# P(both | either): 0.3072916666666667
# P(both | older): 0.49377593360995853
# P(both | either): 0.3090909090909091
# P(both | older): 0.49586776859504134
# P(both | either): 0.31088082901554404
# P(both | older): 0.49586776859504134
# P(both | either): 0.31007751937984496
# P(both | older): 0.49586776859504134
# P(both | either): 0.31007751937984496
# P(both | older): 0.49382716049382713
# P(both | either): 0.30927835051546393
# P(both | older): 0.4918032786885246
# P(both | either): 0.30848329048843187
# P(both | older): 0.4897959183673469
# P(both | either): 0.3076923076923077
# P(both | older): 0.4897959183673469
# P(both | either): 0.3069053708439898
# P(both | older): 0.4878048780487805
# P(both | either): 0.30612244897959184
# P(both | older): 0.4878048780487805
# P(both | either): 0.3053435114503817
# P(both | older): 0.4878048780487805
# P(both | either): 0.3053435114503817
# P(both | older): 0.4878048780487805
# P(both | either): 0.3053435114503817
# P(both | older): 0.4898785425101215
# P(both | either): 0.30710659898477155
# P(both | older): 0.49193548387096775
# P(both | either): 0.30886075949367087
# P(both | older): 0.49193548387096775
# P(both | either): 0.30808080808080807
# P(both | older): 0.4939759036144578
# P(both | either): 0.30982367758186397
# P(both | older): 0.496
# P(both | either): 0.31155778894472363
# P(both | older): 0.496
# P(both | either): 0.3107769423558897
# P(both | older): 0.496
# P(both | either): 0.31
# P(both | older): 0.496
# P(both | either): 0.31
# P(both | older): 0.49800796812749004
# P(both | either): 0.3117206982543641
# P(both | older): 0.49800796812749004
# P(both | either): 0.31094527363184077
# P(both | older): 0.49800796812749004
# P(both | either): 0.31017369727047145
# P(both | older): 0.49603174603174605
# P(both | either): 0.3094059405940594
# P(both | older): 0.49603174603174605
# P(both | either): 0.3094059405940594
# P(both | older): 0.4980237154150198
# P(both | either): 0.3111111111111111
# P(both | older): 0.4980237154150198
# P(both | either): 0.3111111111111111
# P(both | older): 0.49606299212598426
# P(both | either): 0.3103448275862069
# P(both | older): 0.49411764705882355
# P(both | either): 0.3095823095823096
# P(both | older): 0.4921875
# P(both | either): 0.3088235294117647
# P(both | older): 0.490272373540856
# P(both | either): 0.3080684596577017
# P(both | older): 0.490272373540856
# P(both | either): 0.3080684596577017
# P(both | older): 0.4883720930232558
# P(both | either): 0.3073170731707317
# P(both | older): 0.4864864864864865
# P(both | either): 0.30656934306569344
# P(both | older): 0.48846153846153845
# P(both | either): 0.308252427184466
# P(both | older): 0.4904214559386973
# P(both | either): 0.3099273607748184
# P(both | older): 0.49236641221374045
# P(both | either): 0.3115942028985507
# P(both | older): 0.49049429657794674
# P(both | either): 0.3108433734939759
# P(both | older): 0.48863636363636365
# P(both | either): 0.31009615384615385
# P(both | older): 0.4867924528301887
# P(both | either): 0.30935251798561153
# P(both | older): 0.4849624060150376
# P(both | either): 0.30861244019138756
# P(both | older): 0.4868913857677903
# P(both | either): 0.31026252983293556
# P(both | older): 0.4868913857677903
# P(both | either): 0.30952380952380953
# P(both | older): 0.48880597014925375
# P(both | either): 0.31116389548693585
# P(both | older): 0.48698884758364314
# P(both | either): 0.3104265402843602
# P(both | older): 0.48698884758364314
# P(both | either): 0.30969267139479906
# P(both | older): 0.4888888888888889
# P(both | either): 0.3113207547169811
# P(both | older): 0.4888888888888889
# P(both | either): 0.3113207547169811
# P(both | older): 0.4870848708487085
# P(both | either): 0.31058823529411766
# P(both | older): 0.4870848708487085
# P(both | either): 0.30985915492957744
# P(both | older): 0.4870848708487085
# P(both | either): 0.30985915492957744
# P(both | older): 0.4852941176470588
# P(both | either): 0.3091334894613583
# P(both | older): 0.4835164835164835
# P(both | either): 0.308411214953271
# P(both | older): 0.48175182481751827
# P(both | either): 0.3076923076923077
# P(both | older): 0.48175182481751827
# P(both | either): 0.30697674418604654
# P(both | older): 0.48363636363636364
# P(both | either): 0.308584686774942
# P(both | older): 0.48363636363636364
# P(both | either): 0.308584686774942
# P(both | older): 0.4855072463768116
# P(both | either): 0.3101851851851852
# P(both | older): 0.4855072463768116
# P(both | either): 0.3101851851851852
# P(both | older): 0.4855072463768116
# P(both | either): 0.3101851851851852
# P(both | older): 0.4855072463768116
# P(both | either): 0.3094688221709007
# P(both | older): 0.48375451263537905
# P(both | either): 0.3087557603686636
# P(both | older): 0.48201438848920863
# P(both | either): 0.3080459770114943
# P(both | older): 0.48201438848920863
# P(both | either): 0.3080459770114943
# P(both | older): 0.48028673835125446
# P(both | either): 0.3073394495412844
# P(both | older): 0.4785714285714286
# P(both | either): 0.30663615560640733
# P(both | older): 0.4804270462633452
# P(both | either): 0.3082191780821918
# P(both | older): 0.48226950354609927
# P(both | either): 0.3097949886104784
# P(both | older): 0.48056537102473496
# P(both | either): 0.3090909090909091
# P(both | older): 0.48056537102473496
# P(both | either): 0.3090909090909091
# P(both | older): 0.48056537102473496
# P(both | either): 0.3090909090909091
# P(both | older): 0.48056537102473496
# P(both | either): 0.30839002267573695
# P(both | older): 0.4788732394366197
# P(both | either): 0.3076923076923077
# P(both | older): 0.47719298245614034
# P(both | either): 0.30699774266365687
# P(both | older): 0.4755244755244755
# P(both | either): 0.3063063063063063
# P(both | older): 0.4738675958188153
# P(both | either): 0.3056179775280899
# P(both | older): 0.4738675958188153
# P(both | either): 0.3056179775280899
# P(both | older): 0.4738675958188153
# P(both | either): 0.30493273542600896
# P(both | older): 0.4738675958188153
# P(both | either): 0.30493273542600896
# P(both | older): 0.4756944444444444
# P(both | either): 0.30648769574944074
# P(both | older): 0.47750865051903113
# P(both | either): 0.3080357142857143
# P(both | older): 0.4793103448275862
# P(both | either): 0.30957683741648107
# P(both | older): 0.4793103448275862
# P(both | either): 0.30957683741648107
# P(both | older): 0.4793103448275862
# P(both | either): 0.3088888888888889
# P(both | older): 0.4793103448275862
# P(both | either): 0.3088888888888889
# P(both | older): 0.47766323024054985
# P(both | either): 0.3082039911308204
# P(both | older): 0.47766323024054985
# P(both | either): 0.3082039911308204
# P(both | older): 0.47766323024054985
# P(both | either): 0.3075221238938053
# P(both | older): 0.4794520547945205
# P(both | either): 0.3090507726269316
# P(both | older): 0.4794520547945205
# P(both | either): 0.3090507726269316
# P(both | older): 0.4794520547945205
# P(both | either): 0.30837004405286345
# P(both | older): 0.4794520547945205
# P(both | either): 0.3076923076923077
# P(both | older): 0.4812286689419795
# P(both | either): 0.3092105263157895
# P(both | older): 0.48299319727891155
# P(both | either): 0.31072210065645517
# P(both | older): 0.4847457627118644
# P(both | either): 0.31222707423580787
# P(both | older): 0.4847457627118644
# P(both | either): 0.31222707423580787
# P(both | older): 0.4864864864864865
# P(both | either): 0.3137254901960784
# P(both | older): 0.48484848484848486
# P(both | either): 0.3130434782608696
# P(both | older): 0.48322147651006714
# P(both | either): 0.3123644251626898
# P(both | older): 0.48322147651006714
# P(both | either): 0.3123644251626898
# P(both | older): 0.4816053511705686
# P(both | either): 0.3116883116883117
# P(both | older): 0.4816053511705686
# P(both | either): 0.3116883116883117
# P(both | older): 0.4816053511705686
# P(both | either): 0.31101511879049676
# P(both | older): 0.48333333333333334
# P(both | either): 0.3125
# P(both | older): 0.4850498338870432
# P(both | either): 0.3139784946236559
# P(both | older): 0.4850498338870432
# P(both | either): 0.3139784946236559
# P(both | older): 0.4867549668874172
# P(both | either): 0.315450643776824
# P(both | older): 0.4867549668874172
# P(both | either): 0.315450643776824
# P(both | older): 0.48514851485148514
# P(both | either): 0.3147751605995717
# P(both | older): 0.48514851485148514
# P(both | either): 0.3141025641025641
# P(both | older): 0.48514851485148514
# P(both | either): 0.31343283582089554
# P(both | older): 0.48355263157894735
# P(both | either): 0.3127659574468085
# P(both | older): 0.48355263157894735
# P(both | either): 0.3127659574468085
# P(both | older): 0.4852459016393443
# P(both | either): 0.31422505307855625
# P(both | older): 0.4852459016393443
# P(both | either): 0.31422505307855625
# P(both | older): 0.4852459016393443
# P(both | either): 0.31422505307855625
# P(both | older): 0.4852459016393443
# P(both | either): 0.31422505307855625
# P(both | older): 0.4852459016393443
# P(both | either): 0.3135593220338983
# P(both | older): 0.4869281045751634
# P(both | either): 0.3150105708245243
# P(both | older): 0.4869281045751634
# P(both | either): 0.3150105708245243
# P(both | older): 0.48534201954397393
# P(both | either): 0.3143459915611814
# P(both | older): 0.48534201954397393
# P(both | either): 0.3136842105263158
# P(both | older): 0.4837662337662338
# P(both | either): 0.3130252100840336
# P(both | older): 0.4837662337662338
# P(both | either): 0.3130252100840336
# P(both | older): 0.4854368932038835
# P(both | either): 0.31446540880503143
# P(both | older): 0.4854368932038835
# P(both | either): 0.3138075313807531
# P(both | older): 0.4854368932038835
# P(both | either): 0.31315240083507306
# P(both | older): 0.4854368932038835
# P(both | either): 0.31315240083507306
# P(both | older): 0.4854368932038835
# P(both | either): 0.3125
# P(both | older): 0.4854368932038835
# P(both | either): 0.3125
# P(both | older): 0.4838709677419355
# P(both | either): 0.31185031185031187
# P(both | older): 0.4838709677419355
# P(both | either): 0.31185031185031187
# P(both | older): 0.4838709677419355
# P(both | either): 0.31185031185031187
# P(both | older): 0.4838709677419355
# P(both | either): 0.31185031185031187
# P(both | older): 0.4838709677419355
# P(both | either): 0.3112033195020747
# P(both | older): 0.4855305466237942
# P(both | either): 0.31262939958592134
# P(both | older): 0.4855305466237942
# P(both | either): 0.3119834710743802
# P(both | older): 0.483974358974359
# P(both | either): 0.311340206185567
# P(both | older): 0.48242811501597443
# P(both | either): 0.31069958847736623
# P(both | older): 0.48242811501597443
# P(both | either): 0.31069958847736623
# P(both | older): 0.4840764331210191
# P(both | either): 0.31211498973305957
# P(both | older): 0.48253968253968255
# P(both | either): 0.3114754098360656
# P(both | older): 0.48253968253968255
# P(both | either): 0.310838445807771
# P(both | older): 0.48417721518987344
# P(both | either): 0.3122448979591837
# P(both | older): 0.48264984227129337
# P(both | either): 0.31160896130346233
# P(both | older): 0.4811320754716981
# P(both | either): 0.31097560975609756
# P(both | older): 0.4811320754716981
# P(both | either): 0.3103448275862069
# P(both | older): 0.4827586206896552
# P(both | either): 0.3117408906882591
# P(both | older): 0.4827586206896552
# P(both | either): 0.3111111111111111
# P(both | older): 0.4827586206896552
# P(both | either): 0.31048387096774194
# P(both | older): 0.4827586206896552
# P(both | either): 0.30985915492957744
# P(both | older): 0.484375
# P(both | either): 0.3112449799196787
# P(both | older): 0.484375
# P(both | either): 0.3112449799196787
# P(both | older): 0.48286604361370716
# P(both | either): 0.3106212424849699
# P(both | older): 0.4813664596273292
# P(both | either): 0.31
# P(both | older): 0.48297213622291024
# P(both | either): 0.31137724550898205
# P(both | older): 0.48148148148148145
# P(both | either): 0.3107569721115538
# P(both | older): 0.48148148148148145
# P(both | either): 0.3101391650099404
# P(both | older): 0.48
# P(both | either): 0.30952380952380953
# P(both | older): 0.4815950920245399
# P(both | either): 0.3108910891089109
# P(both | older): 0.4801223241590214
# P(both | either): 0.3102766798418972
# P(both | older): 0.47865853658536583
# P(both | either): 0.3096646942800789
# P(both | older): 0.47865853658536583
# P(both | either): 0.3090551181102362
# P(both | older): 0.48024316109422494
# P(both | either): 0.3104125736738703
# P(both | older): 0.48024316109422494
# P(both | either): 0.3104125736738703
# P(both | older): 0.48024316109422494
# P(both | either): 0.30980392156862746
# P(both | older): 0.4818181818181818
# P(both | either): 0.3111545988258317
# P(both | older): 0.4818181818181818
# P(both | either): 0.310546875
# P(both | older): 0.48338368580060426
# P(both | either): 0.31189083820662766
# P(both | older): 0.4819277108433735
# P(both | either): 0.311284046692607
# P(both | older): 0.48348348348348347
# ...
# P(both | older): 0.4993788819875776
# P(both | either): 0.33045622688039455
# P(both | older): 0.49948250879735046
# P(both | either): 0.3305479452054795
# P(both | older): 0.49948250879735046
# P(both | either): 0.3305479452054795
# P(both | older): 0.4993791390728477
# P(both | either): 0.3305026708670045
# P(both | older): 0.4993791390728477
# P(both | either): 0.33045740892906056
# P(both | older): 0.4993791390728477
# P(both | either): 0.33045740892906056
# P(both | older): 0.4993791390728477
# P(both | either): 0.3304121593865535
# P(both | older): 0.4993791390728477
# P(both | either): 0.3303669222343921
# P(both | older): 0.4994827229464101
# P(both | either): 0.33045859000684463
# P(both | older): 0.4994827229464101
# P(both | either): 0.33045859000684463
# P(both | older): 0.4994827229464101
# P(both | either): 0.33045859000684463
# P(both | older): 0.4994827229464101
# P(both | either): 0.33045859000684463
# P(both | older): 0.4994827229464101
# P(both | either): 0.3304133588831098
# P(both | older): 0.49958626396359124
# P(both | either): 0.33050499521007254
# P(both | older): 0.49968976215098243
# P(both | either): 0.33059660645867545
# P(both | older): 0.49979321753515304
# P(both | either): 0.33068819263921195
# P(both | older): 0.4998966301426504
# P(both | either): 0.3307797537619699
# P(both | older): 0.5
# P(both | either): 0.3308712898372316
# P(both | older): 0.5
# P(both | either): 0.33082603938730853
# P(both | older): 0.5
# P(both | either): 0.33082603938730853
# P(both | older): 0.5
# P(both | either): 0.33082603938730853
# P(both | older): 0.5
# P(both | either): 0.33078080131273074
# P(both | older): 0.4998966728662947
# P(both | either): 0.3307355756084222
# P(both | older): 0.4998966728662947
# P(both | either): 0.3307355756084222
# P(both | older): 0.4998966728662947
# P(both | either): 0.33069036226930965
# P(both | older): 0.4998966728662947
# P(both | either): 0.33069036226930965
# P(both | older): 0.5
# P(both | either): 0.330781848004374
# P(both | older): 0.5001032844453626
# P(both | either): 0.33087330873308735
# P(both | older): 0.5001032844453626
# P(both | either): 0.33082809510795297
# P(both | older): 0.5
# P(both | either): 0.330782893837956
# P(both | older): 0.5
# P(both | either): 0.330782893837956
# P(both | older): 0.5
# P(both | either): 0.3307377049180328
# P(both | older): 0.4998967582077225
# P(both | either): 0.3306925283431225
# P(both | older): 0.4998967582077225
# P(both | either): 0.3306925283431225
# P(both | older): 0.5
# P(both | either): 0.33078393881453155
# P(both | older): 0.5001031991744066
# P(both | either): 0.3308753243206336
# P(both | older): 0.5002063557573256
# P(both | either): 0.3309666848716548
# P(both | older): 0.5002063557573256
# P(both | either): 0.33092150170648466
# P(both | older): 0.5003094697751186
# P(both | either): 0.331012831012831
# P(both | older): 0.5003094697751186
# P(both | either): 0.331012831012831
# P(both | older): 0.5003094697751186
# P(both | either): 0.3309676538828989
# P(both | older): 0.5003094697751186
# P(both | either): 0.33092248908296945
# P(both | older): 0.5002062706270627
# P(both | either): 0.3308773366079956
# P(both | older): 0.5001031140441328
# P(both | either): 0.33083219645293316
# P(both | older): 0.5001031140441328
# P(both | either): 0.33083219645293316
# P(both | older): 0.5002061855670104
# P(both | either): 0.3309234756513436
# P(both | older): 0.5002061855670104
# P(both | either): 0.3309234756513436
# P(both | older): 0.5003092145949288
# P(both | either): 0.33101472995090014
# P(both | older): 0.5003092145949288
# P(both | either): 0.33096958952679667
# P(both | older): 0.5004122011541632
# P(both | either): 0.33106081265339515
# P(both | older): 0.5003090871625798
# P(both | either): 0.33101567825494205
# P(both | older): 0.5003090871625798
# P(both | either): 0.33097055616139587
# P(both | older): 0.50041203131438
# P(both | either): 0.33106174185634457
# P(both | older): 0.5005149330587023
# P(both | either): 0.3311529026982829
# P(both | older): 0.5005149330587023
# P(both | either): 0.3311529026982829
# P(both | older): 0.5006177924217463
# P(both | either): 0.33124403869737024
# P(both | older): 0.5005147210212065
# P(both | either): 0.33119891008174385
# P(both | older): 0.5004116920543433
# P(both | either): 0.33115379376106796
# P(both | older): 0.5003087054949578
# P(both | either): 0.3311086897303187
# P(both | older): 0.5002057613168724
# P(both | either): 0.331063597984475
# P(both | older): 0.5002057613168724
# P(both | either): 0.331063597984475
# P(both | older): 0.5002057613168724
# P(both | either): 0.331063597984475
# P(both | older): 0.5001028594939313
# P(both | either): 0.33101851851851855
# P(both | older): 0.5001028594939313
# P(both | either): 0.3309734513274336
# P(both | older): 0.5001028594939313
# P(both | either): 0.33092839640620747
# P(both | older): 0.5001028594939313
# P(both | either): 0.33092839640620747
# P(both | older): 0.5002056766762649
# P(both | either): 0.33101946372669117
# P(both | older): 0.5002056766762649
# P(both | either): 0.33097441480675016
# P(both | older): 0.5002056766762649
# P(both | either): 0.33097441480675016
# P(both | older): 0.500308451573103
# P(both | either): 0.3310654510817798
# P(both | older): 0.5002055921052632
# P(both | either): 0.3310204081632653
# P(both | older): 0.5001027749229188
# P(both | either): 0.3309753774996599
# P(both | older): 0.5001027749229188
# P(both | either): 0.330930359085963
# P(both | older): 0.5001027749229188
# P(both | either): 0.3308853529171767
# P(both | older): 0.5001027749229188
# P(both | either): 0.3308853529171767
# P(both | older): 0.5001027749229188
# P(both | either): 0.33084035898830566
# P(both | older): 0.5001027749229188
# P(both | either): 0.3307953772943576
# P(both | older): 0.5002055076037814
# P(both | either): 0.3308863512778684
# P(both | older): 0.5001027326895419
# P(both | either): 0.3308413755606905
# P(both | older): 0.5001027326895419
# P(both | either): 0.33079641206849686
# P(both | older): 0.5001027326895419
# P(both | either): 0.33075146079630385
# P(both | older): 0.5001027326895419
# P(both | either): 0.33075146079630385
# P(both | older): 0.5001027326895419
# P(both | either): 0.33075146079630385
# P(both | older): 0.5002054231717338
# P(both | either): 0.33084239130434784
# P(both | older): 0.5002054231717338
# P(both | either): 0.33084239130434784
# P(both | older): 0.5002054231717338
# P(both | either): 0.33079744599918487
# P(both | older): 0.5002054231717338
# P(both | either): 0.33079744599918487
# P(both | older): 0.5003080714725816
# P(both | either): 0.33088834555827223
# P(both | older): 0.500205338809035
# P(both | either): 0.3308434062202906
# P(both | older): 0.500205338809035
# P(both | either): 0.3308434062202906
# P(both | older): 0.500205338809035
# P(both | either): 0.3308434062202906
# P(both | older): 0.500205338809035
# P(both | either): 0.3308434062202906
# P(both | older): 0.5003079449804968
# P(both | either): 0.33093427485062465
# P(both | older): 0.5004105090311987
# P(both | either): 0.33102511880515956
# P(both | older): 0.5005130309870717
# P(both | either): 0.33111593809394513
# P(both | older): 0.5004103405826836
# P(both | either): 0.3310709922627935
# P(both | older): 0.5005128205128205
# P(both | either): 0.3311617806731813
# P(both | older): 0.5005128205128205
# P(both | either): 0.3311617806731813
# P(both | older): 0.5006152584085316
# P(both | either): 0.3312525444429366
# P(both | older): 0.5006152584085316
# P(both | either): 0.3312525444429366
# P(both | older): 0.5005126102111954
# P(both | either): 0.3312075983717775
# P(both | older): 0.5005126102111954
# P(both | either): 0.3312075983717775
# P(both | older): 0.5006150061500615
# P(both | either): 0.3312983312983313
# P(both | older): 0.5006150061500615
# P(both | either): 0.3312533912099837
# P(both | older): 0.5006150061500615
# P(both | either): 0.3312533912099837
# P(both | older): 0.5007173601147776
# P(both | either): 0.33134409331344095
# P(both | older): 0.5007173601147776
# P(both | either): 0.33134409331344095
# P(both | older): 0.5007173601147776
# P(both | either): 0.3312991592080282
# P(both | older): 0.5007173601147776
# P(both | either): 0.3312991592080282
# P(both | older): 0.5006147540983606
# P(both | either): 0.3312542372881356
# P(both | older): 0.5005121901249744
# P(both | either): 0.33120932754880694
# P(both | older): 0.5005121901249744
# P(both | either): 0.33120932754880694
# P(both | older): 0.5005121901249744
# P(both | either): 0.33116442998508877
# P(both | older): 0.5006145022531749
# P(both | either): 0.33125508267823256
# P(both | older): 0.5006145022531749
# P(both | either): 0.33125508267823256
# P(both | older): 0.5006145022531749
# P(both | either): 0.33125508267823256
# P(both | older): 0.5006145022531749
# P(both | either): 0.33125508267823256
# P(both | older): 0.5007167724759369
# P(both | either): 0.3313457108009215
# P(both | older): 0.5007167724759369
# P(both | either): 0.3313008130081301
# P(both | older): 0.5007167724759369
# P(both | either): 0.33125592738111365
# P(both | older): 0.5007167724759369
# P(both | either): 0.3312110539149282
# P(both | older): 0.5007167724759369
# P(both | either): 0.33116619260463226
# P(both | older): 0.5006142506142506
# P(both | either): 0.3311213434452871
# P(both | older): 0.5006142506142506
# P(both | either): 0.3310765064319567
# P(both | older): 0.5006142506142506
# P(both | either): 0.3310316815597076
# P(both | older): 0.5006142506142506
# P(both | either): 0.33098686882360906
# P(both | older): 0.5006142506142506
# P(both | either): 0.33098686882360906
# P(both | older): 0.5007164790174002
# P(both | either): 0.3310774228478614
# P(both | older): 0.5007164790174002
# P(both | either): 0.33103261605088646
# P(both | older): 0.5007164790174002
# P(both | either): 0.33103261605088646
# P(both | older): 0.5008186655751126
# P(both | either): 0.33112313937753723
# P(both | older): 0.5008186655751126
# P(both | either): 0.33112313937753723
# P(both | older): 0.5009208103130756
# P(both | either): 0.33121363820863214
# P(both | older): 0.5010229132569558
# P(both | either): 0.3313041125541126
# P(both | older): 0.5009204336265085
# P(both | either): 0.3312592993372109
# P(both | older): 0.5009204336265085
# P(both | either): 0.3312144982418177
# P(both | older): 0.5010224948875256
# P(both | either): 0.33130493576741044
# P(both | older): 0.5010224948875256
# P(both | either): 0.33126014061654946
# P(both | older): 0.5009200572480066
# P(both | either): 0.33121535757739623
# P(both | older): 0.5010220768601799
# P(both | either): 0.3313057583130576
# P(both | older): 0.5010220768601799
# P(both | either): 0.3313057583130576
# P(both | older): 0.5010220768601799
# P(both | either): 0.3313057583130576
# P(both | older): 0.5009196811771919
# P(both | either): 0.33126098121367753
# P(both | older): 0.5009196811771919
# P(both | either): 0.3312162162162162
# P(both | older): 0.5009196811771919
# P(both | either): 0.33117146331576813
# P(both | older): 0.5009196811771919
# P(both | either): 0.3311267225074304
# P(both | older): 0.5010216591744994
# P(both | either): 0.33121707415912466
# P(both | older): 0.5009193054136875
# P(both | either): 0.331172339276067
# P(both | older): 0.5010212418300654
# P(both | either): 0.3312626603646185
# P(both | older): 0.5010212418300654
# P(both | either): 0.3312179314069673
# P(both | older): 0.5010212418300654
# P(both | either): 0.3312179314069673
# P(both | older): 0.5011231366142537
# P(both | either): 0.3313082219522074
# P(both | older): 0.5011231366142537
# P(both | either): 0.3313082219522074
# P(both | older): 0.5011231366142537
# P(both | either): 0.3313082219522074
# P(both | older): 0.5010208248264598
# P(both | either): 0.3312634989200864
# P(both | older): 0.5009185548071035
# P(both | either): 0.33121878796058846
# P(both | older): 0.5009185548071035
# P(both | either): 0.33121878796058846
# P(both | older): 0.5009185548071035
# P(both | either): 0.3311740890688259
# P(both | older): 0.5008163265306123
# P(both | either): 0.33112940223991366
# P(both | older): 0.5008163265306123
# P(both | either): 0.3310847274689692
# P(both | older): 0.5008163265306123
# P(both | either): 0.3310400647511129
# P(both | older): 0.5007141399714344
# P(both | either): 0.3309954140814675
# P(both | older): 0.5006119951040392
# P(both | either): 0.33095077545515844
# P(both | older): 0.5006119951040392
# P(both | either): 0.3309061488673139
# P(both | older): 0.5006119951040392
# P(both | either): 0.3308615343130646
# P(both | older): 0.5005098919029166
# P(both | either): 0.3308169317875438
# P(both | older): 0.5006117455138662
# P(both | either): 0.3309071303410163
# P(both | older): 0.5005096839959225
# P(both | either): 0.3308625336927224
# P(both | older): 0.5004076640847941
# P(both | either): 0.3308179490634685
# P(both | older): 0.5003056857550439
# P(both | either): 0.33077337644839666
# P(both | older): 0.5003056857550439
# P(both | either): 0.33072881584265124
# P(both | older): 0.5004074979625102
# P(both | either): 0.3308189655172414
# P(both | older): 0.5004074979625102
# P(both | either): 0.3308189655172414
# P(both | older): 0.5005092686901609
# P(both | either): 0.33090909090909093
# P(both | older): 0.5004073319755601
# P(both | either): 0.3308645300296256
# P(both | older): 0.5005090612909794
# P(both | either): 0.3309546250168305
# P(both | older): 0.5006107491856677
# P(both | either): 0.3310446957458266
# P(both | older): 0.5007123956849175
# P(both | either): 0.33113474222641004
# P(both | older): 0.5006105006105006
# P(both | either): 0.3310901749663526
# P(both | older): 0.5005086469989827
# P(both | either): 0.3310456197012515
# P(both | older): 0.5005086469989827
# P(both | either): 0.3310456197012515
# P(both | older): 0.5005086469989827
# P(both | either): 0.3310010764262648
# P(both | older): 0.500406834825061
# P(both | either): 0.3309565451365532
# P(both | older): 0.5003050640634533
# P(both | either): 0.3309120258272801
# P(both | older): 0.5003050640634533
# P(both | either): 0.3309120258272801
# P(both | older): 0.5004066693777959
# P(both | either): 0.33100201748486885
# P(both | older): 0.5004066693777959
# P(both | either): 0.33100201748486885
# P(both | older): 0.5004066693777959
# P(both | either): 0.3309575040344271
# P(both | older): 0.5004066693777959
# P(both | either): 0.3309130025547936
# P(both | older): 0.5004066693777959
# P(both | either): 0.3309130025547936
# P(both | older): 0.5004066693777959
# P(both | either): 0.3309130025547936
# P(both | older): 0.5005082333807684
# P(both | either): 0.3310029577843506
# P(both | older): 0.5004065040650406
# P(both | either): 0.3309584621588923
# P(both | older): 0.5003048160942898
# P(both | either): 0.3309139784946237
# P(both | older): 0.5003048160942898
# P(both | either): 0.3308695067867222
# P(both | older): 0.5004063388866314
# P(both | either): 0.33095941951088415
# P(both | older): 0.5005078204346943
# P(both | either): 0.33104930807470107
# P(both | older): 0.5005078204346943
# P(both | either): 0.3310048361096185
# P(both | older): 0.5005078204346943
# P(both | either): 0.3309603760913365
# P(both | older): 0.5004061738424046
# P(both | either): 0.33091592801504166
# P(both | older): 0.5004061738424046
# P(both | either): 0.3308714918759232
# P(both | older): 0.5004061738424046
# P(both | either): 0.3308270676691729
# P(both | older): 0.5004061738424046
# P(both | either): 0.33078265538998525
# P(both | older): 0.500507614213198
# P(both | either): 0.3308724832214765
# P(both | older): 0.5006090133982948
# P(both | either): 0.33096228694135016
# P(both | older): 0.5005074081591232
# P(both | either): 0.3309178743961353
# P(both | older): 0.5006087662337663
# P(both | either): 0.33100764792700926
# P(both | older): 0.5005072022722662
# P(both | either): 0.33096324121277165
# P(both | older): 0.5006085192697769
# P(both | either): 0.3310529845741113
# P(both | older): 0.5007097951733929
# P(both | either): 0.3311427038626609
# P(both | older): 0.5006082725060828
# P(both | either): 0.3310982969022395
# P(both | older): 0.5006082725060828
# P(both | either): 0.33105390185036204
# P(both | older): 0.5005067909993919
# P(both | either): 0.3310095187022389
# P(both | older): 0.5006080259424402
# P(both | either): 0.33109919571045576
# P(both | older): 0.5005065856129686
# P(both | either): 0.3310548183889559
# P(both | older): 0.5005065856129686
# P(both | either): 0.3310548183889559
# P(both | older): 0.5006077795786061
# P(both | either): 0.33114446529080677
# P(both | older): 0.5007089325501317
# P(both | either): 0.3312340881682969
# P(both | older): 0.5007089325501317
# P(both | either): 0.3312340881682969
# P(both | older): 0.5007089325501317
# P(both | either): 0.3311897106109325

# %%
def uniform_pdf(x):
  return 1 if x>=0 and x<1 else 0

# %%
def uniform_cdf(x):
  if x< 0: return 0
  elif x<1: return x
  else: return 1

# %%
def normal_pdf(x, mu=0, sigma=1):
  sqrt_two_pi = math.sqrt(2*math.pi)
  return(math.exp(-(x-mu)**2/2/sigma**2)/(sqrt_two_pi*sigma))

# %%
xs=[x/10.0 for x in range(-50,50)]
plt.plot(xs,[normal_pdf(x,sigma=1) for x in xs],'-',label='mu=0,sigma=1')
plt.plot(xs,[normal_pdf(x,sigma=2) for x in xs],'--',label='mu=0,sigma=2')
plt.plot(xs,[normal_pdf(x,sigma=0.5) for x in xs],':',label='mu=0,sigma=0.5')
plt.plot(xs,[normal_pdf(x,mu=-1) for x in xs],'-.',label='mu=-1,sigma=1')
plt.legend()
plt.title("Various Normal pdfs")
plt.show()

# %%
def normal_cdf(x,mu=0,sigma=1):
  return(1 + math.erf((x-mu)/math.sqrt(2)/sigma))/2

# %%
xs=[x/10.0 for x in range(-50,50)]
plt.plot(xs,[normal_cdf(x,sigma=1) for x in xs],'-',label='mu=0,sigma=1')
plt.plot(xs,[normal_cdf(x,sigma=2) for x in xs],'--',label='mu=0,sigma=2')
plt.plot(xs,[normal_cdf(x,sigma=0.5) for x in xs],':',label='mu=0,sigma=0.5')
plt.plot(xs,[normal_cdf(x,mu=-1) for x in xs],'-.',label='mu=-1,sigma=1')
plt.legend(loc=4)
plt.title("Various Normal cdfs")
plt.show()

# %%
def inverse_normal_cdf(p,mu=0,sigma=1,tolerance=0.00001):
  if mu!=0 or sigma!=1:
    return mu+sigma*inverse_normal_cdf(p,tolerance=tolerance)
  low_z=-10.0
  hi_z=10.0
  while hi_z - low_z>tolerance:
    mid_z=(low_z+hi_z/2)
    mid_p=normal_cdf(mid_Z)
    if mid_p<p:
      hi_z=mid_z
    elif mid_p>p:
      hi_z=mid_z
    else:
      break
  return mid_z

# %%
def bernoulli_trial(p):
  return 1 if random.random()<p else 0

# %%
def binomial(n,p):
  return sum(bernoulli_trial(p) for _ in range(n))

# %%
def make_hist(p,n,num_points):
  data=[binomial(n,p) for _ in range(num_points)]
  histogram=Counter(data)
  plt.bar([x-0.4 for x in histogram.keys()],
         [v/num_points for v in histogram.values()],
         0.8,
         color='0.75')
  mu=p*n
  sigma=math.sqrt(n*p*(1-p))
  xs=range(min(data),max(data) + 1)
  ys=[normal_cdf(i + 0.5, mu, sigma) - normal_cdf(i - 0.5, mu, sigma)
     for i in xs]
  plt.plot(xs,ys)
  plt.title("Binomial Distribution vs. Normal Approximation")
  plt.show()

# %%
make_hist(0.75,100,10000)

# %% [markdown]
# CHAPTER 7

# %%
import math

# %%
def normal_approximation_to_binomial(n,p):
  mu=p*n
  sigma=math,math.sqrt(p*(1-p)*n)
  return mu,sigma

# %%
normal_probability_below=normal_cdf

# %%
def normal_probability_above(lo,mu=0,sigma=1):
  return 1-normal_cdf(lo,mu,sigma)

# %%
def normal_probability_between(lo,hi,mu=0,sigma=1):
  return normal_cdf(hi,mu,sigma)-normal_cdf(lo,mu,sigma)

# %%
def normal_probability_outside(lo,hi,mu=0,sigma=1):
  return 1-normal_probability_between(lo,hi,mu,sigma)

# %%
def normal_upper_bound(probability, mu=0,sigma=1):
  return inverse_normal_cdf(probability,mu,sigma)

# %%
def normal_lower_bound(probability, mu=0,sigma=1):
  return inverse_normal_cdf(1-probability,mu,sigma)

# %%
def normal_two_sided_bounds(probability, mu=0,sigma=1):
  tail_probability=(1-probability)/2
  upper_bound=normal_lower_bound(tail_probability,mu,sigma)
  lower_bound=normal_upper_bound(tail_probability,mu,sigma)
  return lower_bound, upper_bound

# %%
mu_0,sigma_0=normal_approximation_to_binomial(1000,0.5)

# %%
normal_two_sided_bounds(0.95,mu_0,sigma_0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-efdd3e0808fa> in <module>()
# ----> 1 normal_two_sided_bounds(0.95,mu_0,sigma_0)
#
# <ipython-input-63-977782d8a66b> in normal_two_sided_bounds(probability, mu, sigma)
#       1 def normal_two_sided_bounds(probability, mu=0,sigma=1):
#       2   tail_probability=(1-probability)/2
# ----> 3   upper_bound=normal_lower_bound(tail_probability,mu,sigma)
#       4   lower_bound=normal_upper_bound(tail_probability,mu,sigma)
#       5   return lower_bound, upper_bound
#
# <ipython-input-62-cee7f2184052> in normal_lower_bound(probability, mu, sigma)
#       1 def normal_lower_bound(probability, mu=0,sigma=1):
# ----> 2   return inverse_normal_cdf(1-probability,mu,sigma)
#
# <ipython-input-50-06d928adfdec> in inverse_normal_cdf(p, mu, sigma, tolerance)
#       1 def inverse_normal_cdf(p,mu=0,sigma=1,tolerance=0.00001):
#       2   if mu!=0 or sigma!=1:
# ----> 3     return mu+sigma*inverse_normal_cdf(p,tolerance=tolerance)
#       4   low_z=-10.0
#       5   hi_z=10.0
#
# <ipython-input-50-06d928adfdec> in inverse_normal_cdf(p, mu, sigma, tolerance)
#       6   while hi_z - low_z>tolerance:
#       7     mid_z=(low_z+hi_z/2)
# ----> 8     mid_p=normal_cdf(mid_Z)
#       9     if mid_p<p:
#      10       hi_z=mid_z
#
# NameError: name 'mid_Z' is not defined

# %%
def two_sided_p_value(x,mu=0,sigma=1):
  if x>=mu:
    return 2*normal_probability_above(x,mu,sigma)
  else:
    return 2*normal_probability_below(x,mu,sigma)

# %%
two_sided_p_value(529.5,mu_0,sigma_0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-693712c111b9> in <module>()
# ----> 1 two_sided_p_value(529.5,mu_0,sigma_0)
#
# <ipython-input-66-8cb6d6456967> in two_sided_p_value(x, mu, sigma)
#       1 def two_sided_p_value(x,mu=0,sigma=1):
#       2   if x>=mu:
# ----> 3     return 2*normal_probability_above(x,mu,sigma)
#       4   else:
#       5     return 2*normal_probability_below(x,mu,sigma)
#
# <ipython-input-58-ac1f99500d56> in normal_probability_above(lo, mu, sigma)
#       1 def normal_probability_above(lo,mu=0,sigma=1):
# ----> 2   return 1-normal_cdf(lo,mu,sigma)
#
# <ipython-input-48-7b1dc5bda56c> in normal_cdf(x, mu, sigma)
#       1 def normal_cdf(x,mu=0,sigma=1):
# ----> 2   return(1 + math.erf((x-mu)/math.sqrt(2)/sigma))/2
#
# TypeError: unsupported operand type(s) for /: 'float' and 'tuple'

# %%
import random
extreme_value_count=0
for _ in range(1000):
  num_heads=sum(1 if random.random()<0.5 else 0
               for _ in range(1000))
  if num_heads>=530 or num_heads<=470:
    extreme_value_count+=1
print(extreme_value_count/100000)
# Out:
# 0.00067

# %%
two_sided_p_value(531.5, mu_0, sigma_0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-ba160ae4eb04> in <module>()
# ----> 1 two_sided_p_value(531.5, mu_0, sigma_0)
#
# <ipython-input-66-8cb6d6456967> in two_sided_p_value(x, mu, sigma)
#       1 def two_sided_p_value(x,mu=0,sigma=1):
#       2   if x>=mu:
# ----> 3     return 2*normal_probability_above(x,mu,sigma)
#       4   else:
#       5     return 2*normal_probability_below(x,mu,sigma)
#
# <ipython-input-58-ac1f99500d56> in normal_probability_above(lo, mu, sigma)
#       1 def normal_probability_above(lo,mu=0,sigma=1):
# ----> 2   return 1-normal_cdf(lo,mu,sigma)
#
# <ipython-input-48-7b1dc5bda56c> in normal_cdf(x, mu, sigma)
#       1 def normal_cdf(x,mu=0,sigma=1):
# ----> 2   return(1 + math.erf((x-mu)/math.sqrt(2)/sigma))/2
#
# TypeError: unsupported operand type(s) for /: 'float' and 'tuple'

# %%
upper_p_value=normal_probability_above
lower_p_value=normal_probability_below

# %%
upper_p_value(524.5,mu_0,sigma_0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-eb1b9134b277> in <module>()
# ----> 1 upper_p_value(524.5,mu_0,sigma_0)
#
# <ipython-input-58-ac1f99500d56> in normal_probability_above(lo, mu, sigma)
#       1 def normal_probability_above(lo,mu=0,sigma=1):
# ----> 2   return 1-normal_cdf(lo,mu,sigma)
#
# <ipython-input-48-7b1dc5bda56c> in normal_cdf(x, mu, sigma)
#       1 def normal_cdf(x,mu=0,sigma=1):
# ----> 2   return(1 + math.erf((x-mu)/math.sqrt(2)/sigma))/2
#
# TypeError: unsupported operand type(s) for /: 'float' and 'tuple'

# %%
p=0.525
import math
math.sqrt(p*(1-p)/1000)
p_hat=525/1000
mu=p_hat
sigma=math.sqrt(p_hat*(1-p_hat)/1000)
normal_two_sided_bounds(0.95,mu,sigma)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-ccd69e87fac1> in <module>()
#       5 mu=p_hat
#       6 sigma=math.sqrt(p_hat*(1-p_hat)/1000)
# ----> 7 normal_two_sided_bounds(0.95,mu,sigma)
#
# <ipython-input-63-977782d8a66b> in normal_two_sided_bounds(probability, mu, sigma)
#       1 def normal_two_sided_bounds(probability, mu=0,sigma=1):
#       2   tail_probability=(1-probability)/2
# ----> 3   upper_bound=normal_lower_bound(tail_probability,mu,sigma)
#       4   lower_bound=normal_upper_bound(tail_probability,mu,sigma)
#       5   return lower_bound, upper_bound
#
# <ipython-input-62-cee7f2184052> in normal_lower_bound(probability, mu, sigma)
#       1 def normal_lower_bound(probability, mu=0,sigma=1):
# ----> 2   return inverse_normal_cdf(1-probability,mu,sigma)
#
# <ipython-input-50-06d928adfdec> in inverse_normal_cdf(p, mu, sigma, tolerance)
#       1 def inverse_normal_cdf(p,mu=0,sigma=1,tolerance=0.00001):
#       2   if mu!=0 or sigma!=1:
# ----> 3     return mu+sigma*inverse_normal_cdf(p,tolerance=tolerance)
#       4   low_z=-10.0
#       5   hi_z=10.0
#
# <ipython-input-50-06d928adfdec> in inverse_normal_cdf(p, mu, sigma, tolerance)
#       6   while hi_z - low_z>tolerance:
#       7     mid_z=(low_z+hi_z/2)
# ----> 8     mid_p=normal_cdf(mid_Z)
#       9     if mid_p<p:
#      10       hi_z=mid_z
#
# NameError: name 'mid_Z' is not defined

# %%
def run_experiment():
  return[random.random()<0.5 for _ in range(1000)]

# %%
def reject_fairness(experiment):
  num_heads=len([flip for flip in experiment if flip])
  return num_heads < 469 or num_heads >531

# %%
random.seed(0)
experiments=[run_experiment() for _ in range(1000)]
num_rejections=len([experiment
                   for experiment in experiments
                   if reject_fairness(experiment)])
print(num_rejections)
# Out:
# 46

# %%
def estimated_parameters(N,n):
  p=n/N
  sigma=math.sqrt(p*(1-p)/N)
  return p,sigma

# %%
def a_b_test_statistic(N_A,n_A,N_B,n_B):
  p_A,sigma_A=estimated_parameters(N_A,n_A)
  p_B,sigma_B=estimated_parameters(N_B,n_B)
  return(p_B-p_A)/math.sqrt(sigma_A**2+sigma_B**2)

# %%
z=a_b_test_statistic(1000,200,1000,180)

# %%
two_sided_p_value(z)
# Out:
# 0.254141976542236

# %%
z=a_b_test_statistic(1000,200,1000,150)
two_sided_p_value(z)
# Out:
# 0.003189699706216853

# %%
def B(alpha,beta):
  return math.gamma(alpha)*math.gamma(beta)/math.gamma(alpha+beta)

# %%
def beta_pdf(x,alpha,beta):
  if x<= 0 or x>=1:
    return 0
  return x**(alpha-1)*(1-x)**(beta-1)/B(alpha,beta)
